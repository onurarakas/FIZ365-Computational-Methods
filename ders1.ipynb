# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import bilYonMod as bil

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def fonk_y_x(y, x):
    return x**2 - 4*y #bu fonksiyon yalnız bırakılmış y' i vermeli


x0 = 0

y0 = 1

xson = 0.03

n = 10

xTum, yTum = bil.add_coz_euler(fonk_y_x, x0, xson, y0, n)

y=(31/32)*np.exp(-4*xTum) + (1/4)*(xTum**2) - (1/8)*xTum + (1/32)

plt.plot(xTum, yTum, 'o', color = 'r')
plt.plot(xTum, y)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def fonk_V_t(V,t):
    return -V/(220000*10*(10**-6))

V0 = 10

n = 1000

t0 = 0

tson = 10

tTum, VTum = bil.add_coz_euler(fonk_V_t, t0, tson, V0, n)

plt.plot(tTum, VTum, "o")

Vreel = V0**(-tTum/2.2)

plt.plot(tTum, VTum)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Fonksiyon
def fonk_yVek_x(yVek, x):
    dydx = yVek[1]
    return np.array([dydx, x])
# Başlangıç koşulları
y0 = 1
v0 = 0
x0 = 0
xSon = 10
n = 100
# Çöz
xTum, yTum_Vek = bil.add_coz_euler_sistem(fonk_yVek_x, x0, xSon, np.array([y0, v0]), n)
# Analitik çözüm
yAnalitik = xTum**3/6 + 1
vAnalitik = xTum**2/2
# Çiz
fig, ax = plt.subplots(1, 2)
# Sol grafik
ax[0].plot(xTum, yTum_Vek[0], 'o-', label='y(x)', color='red')
ax[0].plot(xTum, yAnalitik, label='y(x) analitik', color='black', linestyle='--')
ax[0].set_xlabel('x')
ax[0].set_ylabel('y(x)')
ax[0].legend()
# Sağ grafik
ax[1].plot(xTum, yTum_Vek[1], 'o-', label='v(x)', color='blue')
ax[1].plot(xTum, vAnalitik, label='v(x) analitik', color='cyan', linestyle='--')
ax[1].set_xlabel('x')
ax[1].set_ylabel('v(x)')
ax[1].legend()
plt.show()
